# %%
# !pip install modelscope
# Out:
# Collecting modelscope
#   Downloading modelscope-1.13.3-py3-none-any.whl.metadata (33 kB)
# Collecting addict (from modelscope)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting attrs (from modelscope)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting datasets>=2.14.5 (from modelscope)
#   Downloading datasets-2.19.0-py3-none-any.whl.metadata (19 kB)
# Collecting einops (from modelscope)
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock>=3.3.0 in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (3.13.4)
# Collecting gast>=0.2.2 (from modelscope)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: huggingface-hub in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (0.22.2)
# Requirement already satisfied: numpy in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (1.26.4)
# Collecting oss2 (from modelscope)
#   Downloading oss2-2.18.4.tar.gz (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 5.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pandas (from modelscope)
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting Pillow>=6.2.0 (from modelscope)
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyarrow!=9.0.0,>=6.0.0 (from modelscope)
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: python-dateutil>=2.1 in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (2.9.0)
# Requirement already satisfied: pyyaml in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (6.0.1)
# Requirement already satisfied: requests>=2.25 in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (2.31.0)
# Collecting scipy (from modelscope)
#   Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (69.5.1)
# Collecting simplejson>=3.3.0 (from modelscope)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.1 kB)
# Collecting sortedcontainers>=1.5.9 (from modelscope)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (4.66.2)
# Requirement already satisfied: urllib3>=1.26 in /home/dk/miniforge3/lib/python3.10/site-packages (from modelscope) (2.2.1)
# Collecting yapf (from modelscope)
#   Downloading yapf-0.40.2-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 7.2 MB/s eta 0:00:00
# Collecting pyarrow-hotfix (from datasets>=2.14.5->modelscope)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.14.5->modelscope)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets>=2.14.5->modelscope)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets>=2.14.5->modelscope)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /home/dk/miniforge3/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets>=2.14.5->modelscope) (2024.3.1)
# Collecting aiohttp (from datasets>=2.14.5->modelscope)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: packaging in /home/dk/miniforge3/lib/python3.10/site-packages (from datasets>=2.14.5->modelscope) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dk/miniforge3/lib/python3.10/site-packages (from huggingface-hub->modelscope) (4.11.0)
# Requirement already satisfied: six>=1.5 in /home/dk/miniforge3/lib/python3.10/site-packages (from python-dateutil>=2.1->modelscope) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dk/miniforge3/lib/python3.10/site-packages (from requests>=2.25->modelscope) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/dk/miniforge3/lib/python3.10/site-packages (from requests>=2.25->modelscope) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dk/miniforge3/lib/python3.10/site-packages (from requests>=2.25->modelscope) (2024.2.2)
# Collecting crcmod>=1.7 (from oss2->modelscope)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2->modelscope)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->modelscope)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->modelscope)
#   Downloading aliyun-python-sdk-core-2.15.1.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytz>=2020.1 (from pandas->modelscope)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->modelscope)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /home/dk/miniforge3/lib/python3.10/site-packages (from yapf->modelscope) (7.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /home/dk/miniforge3/lib/python3.10/site-packages (from yapf->modelscope) (4.2.0)
# Collecting tomli>=2.0.1 (from yapf->modelscope)
#   Downloading tomli-2.0.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting cryptography>=2.6.0 (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope)
#   Downloading cryptography-42.0.5-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets>=2.14.5->modelscope)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets>=2.14.5->modelscope)
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets>=2.14.5->modelscope)
#   Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets>=2.14.5->modelscope)
#   Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting async-timeout<5.0,>=4.0 (from aiohttp->datasets>=2.14.5->modelscope)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: zipp>=0.5 in /home/dk/miniforge3/lib/python3.10/site-packages (from importlib-metadata>=6.6.0->yapf->modelscope) (3.17.0)
# Requirement already satisfied: cffi>=1.12 in /home/dk/miniforge3/lib/python3.10/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope) (1.16.0)
# Requirement already satisfied: pycparser in /home/dk/miniforge3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2->modelscope) (2.22)
# Downloading modelscope-1.13.3-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 5.2 MB/s eta 0:00:0000:0100:01m
# Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 18.9 MB/s eta 0:00:00
# Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 20.7 MB/s eta 0:00:0000:0100:01
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 15.2 MB/s eta 0:00:0000:0100:01
# Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 7.1 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.2 MB/s eta 0:00:00
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.2 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 22.1 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 12.4 MB/s eta 0:00:0000:0100:01
# Downloading yapf-0.40.2-py3-none-any.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 19.8 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 10.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.7 MB/s eta 0:00:00a 0:00:01
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.0 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 22.7 MB/s eta 0:00:00
# Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 21.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.9 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.1 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading cryptography-42.0.5-cp39-abi3-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 21.9 MB/s eta 0:00:0000:0100:01
# Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 kB 20.2 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading multidict-6.0.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 18.0 MB/s eta 0:00:00
# Downloading yarl-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 kB 18.2 MB/s eta 0:00:00
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.18.4-py3-none-any.whl size=115939 sha256=f86cf7f8266860a8edad4c54d6b9294a1b503e6f73e3ec76acdd6fc57d8e33db
#   Stored in directory: /home/dk/.cache/pip/wheels/9e/34/68/f21dc0320c699eb02ab90f2f7965d6f60ee793f03ef5e23212
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.1-py3-none-any.whl size=535325 sha256=077dbc04aaebfdeb6ec31a67562e6c3b0081c29806311077fc41c672f45f80c0
#   Stored in directory: /home/dk/.cache/pip/wheels/69/4b/8e/0a28e00f4cf43b273c18cce083804738d41013e017da922ce4
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=23538 sha256=2bf45792961881bf8844bc672a30695d61463423d6fff3bd0406f122e9ee8e29
#   Stored in directory: /home/dk/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: sortedcontainers, pytz, crcmod, addict, xxhash, tzdata, tomli, simplejson, scipy, pycryptodome, pyarrow-hotfix, pyarrow, Pillow, multidict, jmespath, gast, frozenlist, einops, dill, attrs, async-timeout, yarl, yapf, pandas, multiprocess, cryptography, aiosignal, aliyun-python-sdk-core, aiohttp, aliyun-python-sdk-kms, oss2, datasets, modelscope
# Successfully installed Pillow-10.3.0 addict-2.4.0 aiohttp-3.9.5 aiosignal-1.3.1 aliyun-python-sdk-core-2.15.1 aliyun-python-sdk-kms-2.16.2 async-timeout-4.0.3 attrs-23.2.0 crcmod-1.7 cryptography-42.0.5 datasets-2.19.0 dill-0.3.8 einops-0.7.0 frozenlist-1.4.1 gast-0.5.4 jmespath-0.10.0 modelscope-1.13.3 multidict-6.0.5 multiprocess-0.70.16 oss2-2.18.4 pandas-2.2.2 pyarrow-15.0.2 pyarrow-hotfix-0.6 pycryptodome-3.20.0 pytz-2024.1 scipy-1.13.0 simplejson-3.19.2 sortedcontainers-2.4.0 tomli-2.0.1 tzdata-2024.1 xxhash-3.4.1 yapf-0.40.2 yarl-1.9.4

# %%
from modelscope import AutoModelForCausalLM, AutoTokenizer
device = "cuda" # the device to load the model onto

# Now you do not need to add "trust_remote_code=True"
model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen1.5-7B-Chat",
    torch_dtype="auto",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen1.5-7B-Chat")

# Instead of using model.chat(), we directly use model.generate()
# But you need to use tokenizer.apply_chat_template() to format your inputs as shown below
prompt = "Give me a short introduction to large language model."
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)
model_inputs = tokenizer([text], return_tensors="pt").to(device)

# Directly use generate() and tokenizer.decode() to get the output.
# Use `max_new_tokens` to control the maximum output length.
generated_ids = model.generate(
    model_inputs.input_ids,
    max_new_tokens=512
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/lib/python3.10/site-packages/modelscope/hub/file_download.py:260, in parallel_download(url, local_dir, file_name, cookies, headers, file_size)
#     257 with ThreadPoolExecutor(
#     258         max_workers=parallels,
#     259         thread_name_prefix='download') as executor:
# --> 260     list(executor.map(download_part_with_retry, tasks))
#     262 progress.close()
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     620 if timeout is None:
# --> 621     yield _result_or_cancel(fs.pop())
#     622 else:
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     318 try:
# --> 319     return fut.result(timeout)
#     320 finally:
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       2 device = "cuda" # the device to load the model onto
#       4 # Now you do not need to add "trust_remote_code=True"
# ----> 5 model = AutoModelForCausalLM.from_pretrained(
#       6     "Qwen/Qwen1.5-7B-Chat",
#       7     torch_dtype="auto",
#       8     device_map="auto"
#       9 )
#      10 tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen1.5-7B-Chat")
#      12 # Instead of using model.chat(), we directly use model.generate()
#      13 # But you need to use tokenizer.apply_chat_template() to format your inputs as shown below
#
# File ~/miniforge3/lib/python3.10/site-packages/modelscope/utils/hf_util.py:105, in get_wrapped_class.<locals>.ClassWrapper.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     103 if not os.path.exists(pretrained_model_name_or_path):
#     104     revision = kwargs.pop('revision', DEFAULT_MODEL_REVISION)
# --> 105     model_dir = snapshot_download(
#     106         pretrained_model_name_or_path,
#     107         revision=revision,
#     108         ignore_file_pattern=ignore_file_pattern,
#     109         user_agent=user_agent())
#     110 else:
#     111     model_dir = pretrained_model_name_or_path
#
# File ~/miniforge3/lib/python3.10/site-packages/modelscope/hub/snapshot_download.py:147, in snapshot_download(model_id, revision, cache_dir, user_agent, local_files_only, cookies, ignore_file_pattern)
#     140 url = get_file_download_url(
#     141     model_id=model_id,
#     142     file_path=model_file['Path'],
#     143     revision=revision)
#     145 if MODELSCOPE_PARALLEL_DOWNLOAD_THRESHOLD_MB * 1000 * 1000 < model_file[
#     146         'Size'] and MODELSCOPE_DOWNLOAD_PARALLELS > 1:
# --> 147     parallel_download(
#     148         url,
#     149         temp_cache_dir,
#     150         model_file['Name'],
#     151         headers=headers,
#     152         cookies=None
#     153         if cookies is None else cookies.get_dict(),
#     154         file_size=model_file['Size'])
#     155 else:
#     156     http_get_file(
#     157         url,
#     158         temp_cache_dir,
#     159         model_file['Name'],
#     160         headers=headers,
#     161         cookies=cookies)
#
# File ~/miniforge3/lib/python3.10/site-packages/modelscope/hub/file_download.py:257, in parallel_download(url, local_dir, file_name, cookies, headers, file_size)
#     254     tasks.append((file_name, progress, end + 1, file_size - 1, url,
#     255                   temp_file.name, cookies, headers))
#     256 parallels = MODELSCOPE_DOWNLOAD_PARALLELS if MODELSCOPE_DOWNLOAD_PARALLELS <= 4 else 4
# --> 257 with ThreadPoolExecutor(
#     258         max_workers=parallels,
#     259         thread_name_prefix='download') as executor:
#     260     list(executor.map(download_part_with_retry, tasks))
#     262 progress.close()
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniforge3/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniforge3/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
